# %% [markdown]
# #Print Function

# %%
print("hello python")
# Out:
# hello python

# %%
print("Data Science & Ai")
# Out:
# Data Science & Ai

# %%
print("Data Science","Python")
# Out:
# Data Science Python

# %%
print("khhgv","jhgsfhv",sep="-")
# Out:
# khhgv-jhgsfhv

# %% [markdown]
# #Variables

# %%
name="Sylvia"

# %%
age=24

# %% [markdown]
# #Data Types

# %% [markdown]
# ###Numeric

# %%
x=2 # int

# %%
y=2.66666 #Float

# %% [markdown]
# ###Bool

# %%
flag=True

# %% [markdown]
# ###String

# %%
name="Sylvixb vh,bjn,b,ja" #string=text

# %%
type(name)
# Out:
# str

# %% [markdown]
# #Sequence

# %% [markdown]
# ####List

# %%
my_list=[1,5,80,90]

# %%
type(my_list)
# Out:
# list

# %% [markdown]
# ####Tuple

# %%
tup=(1,80,5,90)

# %% [markdown]
# ####set

# %%
sett={1,80,90,5}

# %% [markdown]
# ####Dictionary

# %%
dic={
    'name':"Mariam",
    'age' : 22,
    'Grade':80
}

# %% [markdown]
# #Convert data types

# %%
x=10
print(type(x))
# Out:
# <class 'int'>

# %%
x=float(x)

# %%
print(type(x))
# Out:
# <class 'float'>

# %%
x=20.5
x=int(x)

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
x=0
x=bool(x)

# %%
x
# Out:
# False

# %% [markdown]
# #Arithmetic Operation

# %%
# Add
print(5+5)
# Out:
# 10

# %%
# Sub
print(5-5)
# Out:
# 0

# %%
# mul
print(5*5)
# Out:
# 25

# %%
# Floor Divion
print(10//3)
# Out:
# 3

# %%
# power
print(3**3)
# Out:
# 27

# %% [markdown]
# #Input

# %%
password=input("Plz enter ur password:   ")
# Out:
# Plz enter ur password:   123

# %%
password=int(input("gscddhgdsvh"))
# Out:
# gscddhgdsvh2

# %% [markdown]
# #String

# %%
s1="my name is sylvia"

# %%
s1="""
    jhhfghjhk
    jhcsguyk
    jkcsghudh
    """

# %%
print(s1)
# Out:
#     jhhfghjhk
#     jhcsguyk
#     jkcsghudh

# %% [markdown]
# #string indexing

# %%
name="Mariam"
name[0]
# Out:
# 'M'

# %%
name[-1]
# Out:
# 'm'

# %% [markdown]
# #Slicing

# %%
x="Hello Python"
x[0:3:2]
# Out:
# 'Hl'

# %%
x[:6]
# Out:
# 'Hello '

# %%
x[::-3]
# Out:
# 'nt l'

# %% [markdown]
# #string operation

# %%
frist_name="mariam "
last_name=" adel"
full_name=frist_name+last_name
print(full_name)
# Out:
# mariam  adel

# %%
first_name="Mariam"*3
print(first_name)
# Out:
# MariamMariamMariam

# %%
x="hello python"
print("python" in x)
print("java" not in x)
# Out:
# True
# True

# %% [markdown]
# #String functions

# %%
name="mariam"

# %%
name.upper()
# Out:
# 'MARIAM'

# %%
name.lower()
# Out:
# 'mariam'

# %%
x="hello-python"
x.split("-")
# Out:
# ['hello', 'python']

# %%
x=10
print(x)
x=100
print(x)
# Out:
# 10
# 100

# %%
number1=10
number2=20
print("number1 + number2 ",number1+number2)
print("number1 - number2 ",number1-number2)
print("number1 * number2 ",number1*number2)
print("number1 / number2 ",number1/number2)
# Out:
# number1 + number2  30
# number1 - number2  -10
# number1 * number2  200
# number1 / number2  0.5

# %%
r=2
pi=3.14
print(pi*r*r)
# Out:
# area = pi*r*r 12.56

# %%
x="Data Science & Ai"
x[13]
# Out:
# '&'

# %% [markdown]
# #List

# %%
#create an empty list
empty_list=[]

#create a list with elements
numbers_list=[1,2,3,4,5]

#create list of names
names_list=["Alice","Bob","Charlie"]

#create mix_list
mix_list=[1,"Alice",3.14,True]

# %%
x=[10,20,30,40]
x[2]
# Out:
# 30

# %%
x[-1]
# Out:
# 40

# %%
x[-2]
# Out:
# 30

# %%
x[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-191521982.py in <cell line: 0>()
# ----> 1 x[5]
#
# IndexError: list index out of range

# %% [markdown]
# #List Slicing

# %%
x=[10,20,30,40,50,60,70,80,90]
x[2:5]
# Out:
# [30, 40, 50]

# %%
x[:3]
# Out:
# [10, 20, 30]

# %%
x[5:]
# Out:
# [60, 70, 80, 90]

# %%
x=['Sylvia','mariam','bosyy']
x[2][1]
# Out:
# 'o'

# %%
x1=['Sylvia','mariam','bosyy']
x2=['Sylvia','mariam','bosyy']
x3=['Sylvia','mariam','bosyy']

x=[x1,x2,x3]
x
# Out:
# [['Sylvia', 'mariam', 'bosyy'],
#  ['Sylvia', 'mariam', 'bosyy'],
#  ['Sylvia', 'mariam', 'bosyy']]

# %%
x[0][1]
# Out:
# 'mariam'

# %%
x=[1,2,3,4,5,6]
len(x)
# Out:
# 6

# %%
min(x)
# Out:
# 1

# %%
max(x)
# Out:
# 6

# %%
sum(x)
# Out:
# 21

# %%
x=[1,2,3,4,5,6]
x.append(7)
x
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
x=[1,2,3,4,5,6]
x.insert(0,0)
x
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
x=[1,2,3,4,5,6]
x.remove(4)
x
# Out:
# [1, 2, 3, 5, 6]

# %%
x=[1,2,3,4,5,6]
x=x.pop(2)
x
# Out:
# 3

# %% [markdown]
# #Tuple

# %%
x=(1,2,3,4,5)
y=("Mariam",20,True)
y[0]
t1=(1,2)
t2=(3,4)
print(t1+t2)
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# #Set

# %%
x={1,2,3,4,5,6}
xx=[1,1,1,1,1,2]
x=set(xx)
x.add(3)
x.add(5)

# %% [markdown]
# #Dictionary

# %%
dic={'name':'Sylvia',
     'age':24,
}
print(dic['name'])
# Out:
# Sylvia

# %%
print(type(dic['name']))
# Out:
# <class 'str'>

# %%
dic.values()
# Out:
# dict_values(['Sylvia', 24])

# %%
dic.items()
# Out:
# dict_items([('name', 'Sylvia'), ('age', 24)])

# %%
dic={'name':'Sylvia',
     'age':24,
}

dic.update({'Grade':80})
print(dic)
# Out:
# {'name': 'Sylvia', 'age': 24, 'Grade': 80}

# %%
dic['age']
# Out:
# 24

# %%
d = {'k1':[1,2,{'k2':['this is tricky',{'tough':[1,2,['hello']]}]}]}

# %%
d['k1'][2]['k2'][1]['tough'][1]
# Out:
# 2
